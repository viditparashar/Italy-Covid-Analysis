# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("covid19_italy_province.csv")
data.head()
# Out:
#    SNo                 Date Country  RegionCode RegionName  ProvinceCode  \
# 0    0  2020-02-24T18:00:00     ITA          13    Abruzzo            66
# 1    1  2020-02-24T18:00:00     ITA          13    Abruzzo            67
# 2    2  2020-02-24T18:00:00     ITA          13    Abruzzo            68
# 3    3  2020-02-24T18:00:00     ITA          13    Abruzzo            69
# 4    4  2020-02-24T18:00:00     ITA          13    Abruzzo           979
#
#                            ProvinceName ProvinceAbbreviation   Latitude  \
# 0                              L'Aquila                   AQ  42.351222
# 1                                Teramo                   TE  42.658918
# 2                               Pescara                   PE  42.464584
# 3                                Chieti                   CH  42.351032
# 4  In fase di definizione/aggiornamento                  NaN        NaN
#
#    Longitude  TotalPositiveCases
# 0  13.398438                   0
# ...

# %%
data.isnull().sum()
# Out:
# SNo                        0
# Date                       0
# Country                    0
# RegionCode                 0
# RegionName                 0
# ProvinceCode               0
# ProvinceName               0
# ProvinceAbbreviation    9779
# Latitude                9492
# Longitude               9492
# TotalPositiveCases         0
# dtype: int64

# %%
data['ProvinceAbbreviation'].fillna(data['ProvinceAbbreviation'].mode()[0],inplace=True)
data['Latitude'].fillna(data['Latitude'].mode()[0], inplace=True)
data['Longitude'].fillna(data['Longitude'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# SNo                     0
# Date                    0
# Country                 0
# RegionCode              0
# RegionName              0
# ProvinceCode            0
# ProvinceName            0
# ProvinceAbbreviation    0
# Latitude                0
# Longitude               0
# TotalPositiveCases      0
# dtype: int64

# %%
data["ProvinceCode"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["ProvinceName"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["ProvinceAbbreviation"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["Latitude"].hist(bins=20)
# Out:
# <Axes: >

# %%
data["Longitude"].hist(bins=20)
# Out:
# <Axes: >

# %%
data.describe()
# Out:
#                 SNo    RegionCode  ProvinceCode      Latitude     Longitude  \
# count  40201.000000  40201.000000  39627.000000  40201.000000  40201.000000
# mean   20100.000000     10.357354      0.322382     41.495753     10.968814
# std    11605.173423      5.993795      0.361967      3.427444      3.085826
# min        0.000000      1.000000     -2.363952     36.925092      7.320149
# 25%    10050.000000      5.000000      0.249951     37.059917      7.551172
# 50%    20100.000000      9.000000      0.373750     41.892770     10.792774
# 75%    30150.000000     16.000000      0.436747     44.801074     13.453072
# max    40200.000000     22.000000      0.658814     46.499335     18.171897
#
#        TotalPositiveCases
# count        40201.000000
# mean          2563.579961
# std           6884.484083
# min              0.000000
# 25%            103.000000
# 50%            642.000000
# 75%           2605.000000
# max         158717.000000

# %%
sns.relplot(x="RegionCode",y="TotalPositiveCases", data=data)

# %%
data["RegionCode"] = np.log(data["RegionCode"])

# %%
sns.lineplot(x="RegionCode",y="TotalPositiveCases", data=data)
# Out:
# <Axes: xlabel='RegionCode', ylabel='TotalPositiveCases'>

# %%
sns.pairplot(data)

# %%
sns.catplot(data)
